# %% [markdown]
# # Based on Keras

# %%
# Required imports
#from numpy import concatenate
from math import sqrt
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
import plotly.offline as py
from plotly.offline import iplot
import plotly.graph_objs as go
import numpy as np
import os
import pandas as pd
path = './data'
filename_read = os.path.join(path, 'WCOILWTICO.csv')
df = pd.read_csv(filename_read)

data = df.set_index('DATE') # set_index @ https://blog.csdn.net/jingyi130705008/article/details/78162758/
# Out:
# Using TensorFlow backend.

# %%
py.init_notebook_mode(connected=True)
# %matplotlib inline
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Plot the data read_in
cop_trace = go.Scatter(x=data.index, y=data['WCOILWTICO'], name= 'Price')
py.plot([cop_trace])
# Out:
# 'file:///Users/marenwen/env/practice_hands_on_ml/RNN/temp-plot.html'

# %%
# Create a scaled version of the data with oil prices normalized between 0 and 1
values = data['WCOILWTICO'].values.reshape(-1, 1) # pd.values.reshape() @ https://stackoverflow.com/questions/14390224/reshape-of-pandas-series
values = values.astype('float32') # the initial dtype is float64

#对数据作归一化
scaler  =MinMaxScaler(feature_range=(0, 1)) 
scaled = scaler.fit_transform(values)
scaled
# Out:
# array([[0.11237834],
#        [0.11397506],
#        [0.10317821],
#        ...,
#        [0.38229924],
#        [0.40381688],
#        [0.4103558 ]], dtype=float32)

# %%
# Split data between training and testing
# 把原数据的前70%取来作training set，后30%作testing/validation set。
train_size = int(len(scaled) * 0.7)
test_size = int(len(scaled) - train_size)
train, test = scaled[0:train_size], scaled[train_size:]

# 输出： train set数据样本数量， test set数据样本数量
print(len(train), len(test))

#train[3, 0]
# Out:
# 1178 505

# %%
# Generates the X and Y data from the downloaded dataset. The last n values in the input data are left off
# and the Y values are generated by shifting the X values by n 
# where n is  the value of the prev_periods paramater

# See the example below , prev_periods is set to 2
# Original X (weeks 1 - 5) = 1.05, 1.15, 1.25, 1.35, 1.45
# New X (weeks 1 - 3) = 1.05, 1.15, 1.25
# Y = 1.25, 1.35, 1.45

#这个函数可能是这份代码里最难懂的部分。
#该函数目的是，生成输入的X data set和label Y data set。Y的生成：把所有X的数据在时间轴上往后移动prev_periods个单位。
# 即Y是X的未来数据。
# Pay attention to the type of datset, is it a list, an ndarray, or a Set?
def gen_datasets(dataset, prev_periods):
    dataX, dataY = [], []
    for i in range(len(dataset) - prev_periods):
        a = dataset[i:(i  + prev_periods), 0] # dataset[train/test, axis = none], axis = 0 transferes columns vector to row vector
        dataX.append(a)
        dataY.append(dataset[i + prev_periods, 0])
    print(len(dataY))
    
    return np.array(dataX), np.array(dataY)

# %%
# Generate testing and validation data
# Use a slding window of size 1 week to predict next week oil price
# 此处通过gen_datsets（）函数，分别生成train set和test set；每个set里都有X和Y。
prev_periods = 1
trainX, trainY = gen_datasets(train, prev_periods)
testX, testY = gen_datasets(test, prev_periods)
# Out:
# 1177
# 504

# %%
# 看一下生成的set是怎样shape的矩阵
trainX.shape[0], trainX.shape[1], trainX.shape
# Out:
# (1177, 1, (1177, 1))

# %%
# Reshape into a numpy array of shape (m, 1, prev_periods) where m is the number of training or testing values

# %%
# 修改上一步生成矩阵的纬度，以便后续计算的方便（数据本身并没有发生变化）。
trainX =  np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

# %% [markdown]
# # Keras Based RNN Model Building

# %%
# Build RNN construction model based on Keras
# 构建RNN结构的代码都在这儿了。这里构建LSTM框架的过程；同时把之前若干步骤处理好的矩阵形式的数据喂在个框架里；下一步进行训练。
# 这里涉及到的，基于tensorflow后端的keras的代码API，具体每个函数和函数参数的意义，推荐参考keras的官方中文文档（实在太多了。。。）
model = Sequential()
model.add(LSTM(100, input_shape = (trainX.shape[1], trainX.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae', 'acc'])
history = model.fit(trainX, trainY, epochs = 50, batch_size = 32, validation_data = (testX, testY), verbose = 0, shuffle = None)

# %%
training_error = model.evaluate(trainX, trainY, verbose = 0)
testing_error = model.evaluate(testX, testY, verbose=0)
print('Training error: %.5f MSE (%.5f RMSE) %.5f MAE' % (training_error[0], sqrt(training_error[0]), training_error[1]))
print('Testing error: %.5f MSE (%.5f RMSE) %.5f MAE' % (testing_error[0], sqrt(testing_error[0]), testing_error[1]))
# Out:
# Training error: 0.00016 MSE (0.01276 RMSE) 0.00991 MAE
# Testing error: 0.00053 MSE (0.02306 RMSE) 0.01676 MAE

# %%
# 接下来是可视化的展示。
# 下面这个图，是看training和testing sets的X和Y的训练结果，即两者结果上loss各自差了多少。
# 结果显示，loss逐渐相差不大，趋于拟合。
# Plot validation loss  vs epoch number
pyplot.plot(history.history['loss'], label='training loss')
pyplot.plot(history.history['val_loss'], label='test loss')
pyplot.legend()
pyplot.show()

# %%
testX
# Out:
# array([[[0.8635188 ]],
#
#        [[0.8196472 ]],
#
#        [[0.7861922 ]],
#
#        [[0.7960766 ]],
#
#        [[0.79904187]],
#
#        [[0.74034363]],
#
#        [[0.6986009 ]],
#
#        [[0.6553376 ]],
#
#        [[0.761253  ]],
#
#        [[0.6507755 ]],
#
#        [[0.57208025]],
#
#        [[0.48806262]],
#
#        [[0.437652  ]],
#
#        [[0.41218063]],
#
#        [[0.40533754]],
#
#        [[0.36192212]],
#
#        [[0.3137165 ]],
#
#        [[0.32139596]],
#
#        [[0.26307783]],
#
#        [[0.2552463 ]],
#
#        [[0.21821776]],
#
#        [[0.16712284]],
#
#        [[0.23874694]],
#
#        [[0.25440994]],
#
#        [[0.19563562]],
#
#        [[0.23684609]],
#
#        [[0.24102795]],
#
#        [[0.2264294 ]],
#
#        [[0.19723234]],
#
#        [[0.19882905]],
#
#        [[0.2288625 ]],
#
#        [[0.2446776 ]],
#
#        [[0.26353404]],
#
#        [[0.2926551 ]],
#
#        [[0.319267  ]],
#
#        [[0.29911798]],
#
#        [[0.30003038]],
#
#        [[0.29546836]],
#
#        [[0.27980533]],
#
#        [[0.2980535 ]],
#
#        [[0.34184912]],
#
#        [[0.35690385]],
#
#        [[0.37499997]],
#
#        [[0.4054136 ]],
#
#        [[0.4342305 ]],
#
#        [[0.45506382]],
#
#        [[0.45331508]],
#
#        [[0.4378041 ]],
#
#        [[0.4434306 ]],
#
#        [[0.3838199 ]],
#
#        [[0.38237527]],
#
#        [[0.41271284]],
#
#        [[0.42601883]],
#
#        [[0.46061432]],
#
#        [[0.44586372]],
#
#        [[0.45468366]],
#
#        [[0.46662104]],
#
#        [[0.43635947]],
#
#        [[0.4555201 ]],
#
#        [[0.45863742]],
#
#        [[0.43590325]],
#
#        [[0.43978095]],
#
#        [[0.45468366]],
#
#        [[0.4921685 ]],
#
#        [[0.5250912 ]],
#
#        [[0.5130018 ]],
#
#        [[0.5170316 ]],
#
#        [[0.511253  ]],
#
#        [[0.5122415 ]],
#
#        [[0.49528587]],
#
#        [[0.5003801 ]],
#
#        [[0.4600821 ]],
#
#        [[0.4616788 ]],
#
#        [[0.4847932 ]],
#
#        [[0.5175638 ]],
#
#        [[0.54242694]],
#
#        [[0.5250912 ]],
#
#        [[0.49893552]],
#
#        [[0.47855836]],
#
#        [[0.4833485 ]],
#
#        [[0.47810215]],
#
#        [[0.51132905]],
#
#        [[0.51870435]],
#
#        [[0.52607965]],
#
#        [[0.53801703]],
#
#        [[0.5355839 ]],
#
#        [[0.52957726]],
#
#        [[0.5475213 ]],
#
#        [[0.5676703 ]],
#
#        [[0.55763376]],
#
#        [[0.54668486]],
#
#        [[0.5567214 ]],
#
#        [[0.5264598 ]],
#
#        [[0.48646593]],
#
#        [[0.44206202]],
#
#        [[0.45331508]],
#
#        [[0.4707269 ]],
#
#        [[0.47475666]],
#
#        [[0.49954373]],
#
#        [[0.50228095]],
#
#        [[0.48631382]],
#
#        [[0.4819799 ]],
#
#        [[0.49688256]],
#
#        [[0.50608265]],
#
#        [[0.51034063]],
#
#        [[0.5382451 ]],
#
#        [[0.51072073]],
#
#        [[0.4854014 ]],
#
#        [[0.4707269 ]],
#
#        [[0.47916663]],
#
#        [[0.48524934]],
#
#        [[0.4913321 ]],
#
#        [[0.47718978]],
#
#        [[0.5125456 ]],
#
#        [[0.5420468 ]],
#
#        [[0.54105836]],
#
#        [[0.53337896]],
#
#        [[0.5400699 ]],
#
#        [[0.5621198 ]],
#
#        [[0.57717454]],
#
#        [[0.54159063]],
#
#        [[0.54197073]],
#
#        [[0.575958  ]],
#
#        [[0.589264  ]],
#
#        [[0.5875151 ]],
#
#        [[0.5980839 ]],
#
#        [[0.6080444 ]],
#
#        [[0.5971715 ]],
#
#        [[0.6084245 ]],
#
#        [[0.59876823]],
#
#        [[0.57109183]],
#
#        [[0.5970194 ]],
#
#        [[0.5665298 ]],
#
#        [[0.55603707]],
#
#        [[0.64066297]],
#
#        [[0.6846867 ]],
#
#        [[0.7051398 ]],
#
#        [[0.6751064 ]],
#
#        [[0.71023417]],
#
#        [[0.71532845]],
#
#        [[0.7473388 ]],
#
#        [[0.7356295 ]],
#
#        [[0.74597013]],
#
#        [[0.77022505]],
#
#        [[0.721107  ]],
#
#        [[0.6757147 ]],
#
#        [[0.6614203 ]],
#
#        [[0.6732816 ]],
#
#        [[0.68369824]],
#
#        [[0.6770833 ]],
#
#        [[0.6453011 ]],
#
#        [[0.62119824]],
#
#        [[0.62880164]],
#
#        [[0.65480536]],
#
#        [[0.651764  ]],
#
#        [[0.66157234]],
#
#        [[0.66020375]],
#
#        [[0.60713196]],
#
#        [[0.54638076]],
#
#        [[0.5653893 ]],
#
#        [[0.5631082 ]],
#
#        [[0.5859945 ]],
#
#        [[0.58477795]],
#
#        [[0.5925334 ]],
#
#        [[0.5523874 ]],
#
#        [[0.533607  ]],
#
#        [[0.52030104]],
#
#        [[0.5653132 ]],
#
#        [[0.5764902 ]],
#
#        [[0.61830896]],
#
#        [[0.6253041 ]],
#
#        [[0.6536648 ]],
#
#        [[0.6715328 ]],
#
#        [[0.6530565 ]],
#
#        [[0.67601883]],
#
#        [[0.6773114 ]],
#
#        [[0.6467457 ]],
#
#        [[0.65951943]],
#
#        [[0.67525846]],
#
#        [[0.69487524]],
#
#        [[0.6799726 ]],
#
#        [[0.67632294]],
#
#        [[0.6717609 ]],
#
#        [[0.65997565]],
#
#        [[0.6657542 ]],
#
#        [[0.68985707]],
#
#        [[0.7312956 ]],
#
#        [[0.7338807 ]],
#
#        [[0.72475666]],
#
#        [[0.7234641 ]],
#
#        [[0.725441  ]],
#
#        [[0.71563256]],
#
#        [[0.7034671 ]],
#
#        [[0.69609183]],
#
#        [[0.70065385]],
#
#        [[0.705444  ]],
#
#        [[0.703087  ]],
#
#        [[0.6537409 ]],
#
#        [[0.6243157 ]],
#
#        [[0.60736006]],
#
#        [[0.578315  ]],
#
#        [[0.5583181 ]],
#
#        [[0.54949814]],
#
#        [[0.5330748 ]],
#
#        [[0.5263838 ]],
#
#        [[0.56827855]],
#
#        [[0.56858265]],
#
#        [[0.6032542 ]],
#
#        [[0.59215325]],
#
#        [[0.593826  ]],
#
#        [[0.6245437 ]],
#
#        [[0.63435215]],
#
#        [[0.6479623 ]],
#
#        [[0.6438564 ]],
#
#        [[0.6438564 ]],
#
#        [[0.6581508 ]],
#
#        [[0.62880164]],
#
#        [[0.61093366]],
#
#        [[0.6068278 ]],
#
#        [[0.6114659 ]],
#
#        [[0.61275846]],
#
#        [[0.5729166 ]],
#
#        [[0.56926703]],
#
#        [[0.5701034 ]],
#
#        [[0.56926703]],
#
#        [[0.5809002 ]],
#
#        [[0.5799117 ]],
#
#        [[0.57785887]],
#
#        [[0.56805044]],
#
#        [[0.58728707]],
#
#        [[0.6017335 ]],
#
#        [[0.62173045]],
#
#        [[0.6263686 ]],
#
#        [[0.6354927 ]],
#
#        [[0.6418035 ]],
#
#        [[0.65640205]],
#
#        [[0.6476581 ]],
#
#        [[0.6535127 ]],
#
#        [[0.6339719 ]],
#
#        [[0.61732054]],
#
#        [[0.6082725 ]],
#
#        [[0.62119824]],
#
#        [[0.62385947]],
#
#        [[0.6468978 ]],
#
#        [[0.63921833]],
#
#        [[0.62621653]],
#
#        [[0.5854623 ]],
#
#        [[0.6082725 ]],
#
#        [[0.62652063]],
#
#        [[0.64507294]],
#
#        [[0.6360249 ]],
#
#        [[0.63686126]],
#
#        [[0.62591237]],
#
#        [[0.63298357]],
#
#        [[0.64902675]],
#
#        [[0.6512317 ]],
#
#        [[0.64499694]],
#
#        [[0.68164533]],
#
#        [[0.7124391 ]],
#
#        [[0.7290145 ]],
#
#        [[0.7214111 ]],
#
#        [[0.718826  ]],
#
#        [[0.7160127 ]],
#
#        [[0.7296989 ]],
#
#        [[0.71836984]],
#
#        [[0.7400395 ]],
#
#        [[0.74338496]],
#
#        [[0.7402676 ]],
#
#        [[0.72399634]],
#
#        [[0.7002737 ]],
#
#        [[0.7005778 ]],
#
#        [[0.6972323 ]],
#
#        [[0.68818426]],
#
#        [[0.65822685]],
#
#        [[0.6534367 ]],
#
#        [[0.6334397 ]],
#
#        [[0.6306265 ]],
#
#        [[0.6304744 ]],
#
#        [[0.6232512 ]],
#
#        [[0.6478862 ]],
#
#        [[0.65564173]],
#
#        [[0.6603558 ]],
#
#        [[0.6702402 ]],
#
#        [[0.6498631 ]],
#
#        [[0.6190693 ]],
#
#        [[0.62332726]],
#
#        [[0.64773417]],
#
#        [[0.6560979 ]],
#
#        [[0.65982354]],
#
#        [[0.67829984]],
#
#        [[0.6989811 ]],
#
#        [[0.6977645 ]],
#
#        [[0.7000456 ]],
#
#        [[0.6732816 ]],
#
#        [[0.6749543 ]],
#
#        [[0.6817214 ]],
#
#        [[0.6802007 ]],
#
#        [[0.6973844 ]],
#
#        [[0.70673656]],
#
#        [[0.69274634]],
#
#        [[0.68058085]],
#
#        [[0.6789081 ]],
#
#        [[0.69130164]],
#
#        [[0.70574814]],
#
#        [[0.70673656]],
#
#        [[0.7012622 ]],
#
#        [[0.7220955 ]],
#
#        [[0.73167574]],
#
#        [[0.72756994]],
#
#        [[0.7186739 ]],
#
#        [[0.70141417]],
#
#        [[0.6947232 ]],
#
#        [[0.70977795]],
#
#        [[0.6933546 ]],
#
#        [[0.6576946 ]],
#
#        [[0.65518546]],
#
#        [[0.6383059 ]],
#
#        [[0.6481903 ]],
#
#        [[0.63153887]],
#
#        [[0.61914533]],
#
#        [[0.627433  ]],
#
#        [[0.6246198 ]],
#
#        [[0.611618  ]],
#
#        [[0.582649  ]],
#
#        [[0.5465328 ]],
#
#        [[0.54075426]],
#
#        [[0.5344434 ]],
#
#        [[0.511253  ]],
#
#        [[0.4980231 ]],
#
#        [[0.48950726]],
#
#        [[0.466545  ]],
#
#        [[0.42715937]],
#
#        [[0.38123477]],
#
#        [[0.34131688]],
#
#        [[0.33895984]],
#
#        [[0.32268852]],
#
#        [[0.28718063]],
#
#        [[0.27425483]],
#
#        [[0.26961675]],
#
#        [[0.26094887]],
#
#        [[0.3009428 ]],
#
#        [[0.3052007 ]],
#
#        [[0.30938256]],
#
#        [[0.29014596]],
#
#        [[0.29942212]],
#
#        [[0.27896893]],
#
#        [[0.2538777 ]],
#
#        [[0.28649634]],
#
#        [[0.2882451 ]],
#
#        [[0.31006688]],
#
#        [[0.3328771 ]],
#
#        [[0.34321773]],
#
#        [[0.357208  ]],
#
#        [[0.37051395]],
#
#        [[0.3726429 ]],
#
#        [[0.3645833 ]],
#
#        [[0.3588047 ]],
#
#        [[0.36998174]],
#
#        [[0.37309912]],
#
#        [[0.3717305 ]],
#
#        [[0.3726429 ]],
#
#        [[0.35675177]],
#
#        [[0.31462893]],
#
#        [[0.30930656]],
#
#        [[0.29052612]],
#
#        [[0.2806417 ]],
#
#        [[0.2580596 ]],
#
#        [[0.24482965]],
#
#        [[0.23068732]],
#
#        [[0.22604924]],
#
#        [[0.2716697 ]],
#
#        [[0.25973234]],
#
#        [[0.26216543]],
#
#        [[0.26284972]],
#
#        [[0.2585158 ]],
#
#        [[0.28406325]],
#
#        [[0.27235398]],
#
#        [[0.25973234]],
#
#        [[0.25843978]],
#
#        [[0.26596713]],
#
#        [[0.24102795]],
#
#        [[0.22521287]],
#
#        [[0.22422445]],
#
#        [[0.22354013]],
#
#        [[0.19715631]],
#
#        [[0.18841237]],
#
#        [[0.19206202]],
#
#        [[0.19761252]],
#
#        [[0.17982057]],
#
#        [[0.14895073]],
#
#        [[0.13830596]],
#
#        [[0.15822688]],
#
#        [[0.15404502]],
#
#        [[0.13032237]],
#
#        [[0.14461678]],
#
#        [[0.1545012 ]],
#
#        [[0.1781478 ]],
#
#        [[0.20293489]],
#
#        [[0.20772505]],
#
#        [[0.21631691]],
#
#        [[0.19631994]],
#
#        [[0.19555959]],
#
#        [[0.22985095]],
#
#        [[0.2346411 ]],
#
#        [[0.2531934 ]],
#
#        [[0.25258514]],
#
#        [[0.2618613 ]],
#
#        [[0.28125   ]],
#
#        [[0.28680047]],
#
#        [[0.2889294 ]],
#
#        [[0.29790145]],
#
#        [[0.28048962]],
#
#        [[0.28672442]],
#
#        [[0.28261858]],
#
#        [[0.26741177]],
#
#        [[0.26307783]],
#
#        [[0.2542579 ]],
#
#        [[0.234413  ]],
#
#        [[0.22673357]],
#
#        [[0.24414536]],
#
#        [[0.27493915]],
#
#        [[0.27410278]],
#
#        [[0.25935218]],
#
#        [[0.26581505]],
#
#        [[0.25349754]],
#
#        [[0.2553984 ]],
#
#        [[0.27030107]],
#
#        [[0.29257905]],
#
#        [[0.29873782]],
#
#        [[0.30079073]],
#
#        [[0.29166666]],
#
#        [[0.2623935 ]],
#
#        [[0.25555047]],
#
#        [[0.2596563 ]],
#
#        [[0.27562347]],
#
#        [[0.28611615]],
#
#        [[0.30390814]],
#
#        [[0.31105533]],
#
#        [[0.31135947]],
#
#        [[0.32390508]],
#
#        [[0.3219282 ]],
#
#        [[0.31227186]],
#
#        [[0.310371  ]],
#
#        [[0.31736618]],
#
#        [[0.32185218]],
#
#        [[0.31843063]],
#
#        [[0.3210158 ]],
#
#        [[0.32717454]],
#
#        [[0.32360095]],
#
#        [[0.3003345 ]],
#
#        [[0.2815541 ]],
#
#        [[0.27585155]],
#
#        [[0.28999388]],
#
#        [[0.3061131 ]],
#
#        [[0.32078767]],
#
#        [[0.30482054]],
#
#        [[0.28984183]],
#
#        [[0.2753193 ]],
#
#        [[0.27402675]],
#
#        [[0.29075426]],
#
#        [[0.29812953]],
#
#        [[0.28497565]],
#
#        [[0.27045313]],
#
#        [[0.26079682]],
#
#        [[0.24399328]],
#
#        [[0.25570256]],
#
#        [[0.25821164]],
#
#        [[0.2623935 ]],
#
#        [[0.2692366 ]],
#
#        [[0.28337893]],
#
#        [[0.2928832 ]],
#
#        [[0.2895377 ]],
#
#        [[0.27767637]],
#
#        [[0.27889293]],
#
#        [[0.27128953]],
#
#        [[0.285736  ]],
#
#        [[0.28946164]],
#
#        [[0.29744524]],
#
#        [[0.30999085]],
#
#        [[0.2982816 ]],
#
#        [[0.30238745]],
#
#        [[0.30976278]],
#
#        [[0.31561735]],
#
#        [[0.33143246]],
#
#        [[0.35013682]],
#
#        [[0.3407086 ]],
#
#        [[0.35333028]],
#
#        [[0.35591543]],
#
#        [[0.3491484 ]],
#
#        [[0.35104924]],
#
#        [[0.3563716 ]],
#
#        [[0.37165448]],
#
#        [[0.3829075 ]],
#
#        [[0.39735398]],
#
#        [[0.40123174]],
#
#        [[0.4116484 ]],
#
#        [[0.413017  ]],
#
#        [[0.38784972]],
#
#        [[0.3768248 ]],
#
#        [[0.39134732]],
#
#        [[0.38830593]],
#
#        [[0.38511252]],
#
#        [[0.38229924]],
#
#        [[0.40381688]]], dtype=float32)

# %%
# Plot prediction vs actual using scaled values (0, 1)。这里的纵轴数据是归一化后的oil price，分布0到1.
# 用之前训练好的参数，对我们的testing set 504个数据作预测，得到一个yhat_test数据集；然后和原来真实的504个数据作对比，发现拟合非常好。
# 说实话，我也不知道model.predict这个函数内部究竟发生了什么。。
yhat_test = model.predict(testX)
print(yhat_test.shape)

pyplot.plot(yhat_test, color='red', label='prediction')
pyplot.plot(testY, color='blue', label='actual')
pyplot.legend()
pyplot.show()
# Out:
# (504, 1)

# %%
# 下面的过程只是把原来经过归一化的数据convert回归一化之前的数据oil prices，使得数据的呈现和现实数据更贴近。
# Convert scaled prices back to original scale (USD)
yhat_test_inverse = scaler.inverse_transform(yhat_test.reshape(-1, 1))
testY_inverse = scaler.inverse_transform(testY.reshape(-1, 1))

# Add dates back
dates = data.tail(len(testX)).index
testY_reshape = testY_inverse.reshape(len(testY_inverse))
yhat_test_reshape = yhat_test_inverse.reshape(len(yhat_test_inverse))

# %%
# Calculate MSE< RMSE based on original USD prices
mse = mean_squared_error(testY_inverse, yhat_test_inverse)
rmse = sqrt(mse)
print('Test MSE(USD): %.3f Test RMSE(USD): %.3f' % (mse, rmse))
# Out:
# Test MSE(USD): 9.197 Test RMSE(USD): 3.033

# %%
# Plot actual vs predicted using actual dates and USD
actual = go.Scatter(x=dates, y=testY_reshape, line = dict(color = ('rgb(0, 0, 255)'), width = 4), name= 'Actual Price')
predicted = go.Scatter(x=dates, y=yhat_test_reshape, line = dict(color = ('rgb(255, 0, 0)'), width = 4), name= 'Predicted Price')
py.iplot([predicted, actual])
py.plot([predicted, actual])
# Out:
# <div id="43046fdc-9bf7-471f-a8d6-f1afaf637764" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("43046fdc-9bf7-471f-a8d6-f1afaf637764", [{"line": {"color": "rgb(255, 0, 0)", "width": 4}, "name": "Predicted Price", "x": ["2008-08-08", "2008-08-15", "2008-08-22", "2008-08-29", "2008-09-05", "2008-09-12", "2008-09-19", "2008-09-26", "2008-10-03", "2008-10-10", "2008-10-17", "2008-10-24", "2008-10-31", "2008-11-07", "2008-11-14", "2008-11-21", "2008-11-28", "2008-12-05", "2008-12-12", "2008-12-19", "2008-12-26", "2009-01-02", "2009-01-09", "2009-01-16", "2009-01-23", "2009-01-30", "2009-02-06", "2009-02-13", "2009-02-20", "2009-02-27", "2009-03-06", "2009-03-13", "2009-03-20", "2009-03-27", "2009-04-03", "2009-04-10", "2009-04-17", "2009-04-24", "2009-05-01", "2009-05-08", "2009-05-15", "2009-05-22", "2009-05-29", "2009-06-05", "2009-06-12", "2009-06-19", "2009-06-26", "2009-07-03", "2009-07-10", "2009-07-17", "2009-07-24", "2009-07-31", "2009-08-07", "2009-08-14", "2009-08-21", "2009-08-28", "2009-09-04", "2009-09-11", "2009-09-18", "2009-09-25", "2009-10-02", "2009-10-09", "2009-10-16", "2009-10-23", "2009-10-30", "2009-11-06", "2009-11-13", "2009-11-20", "2009-11-27", "2009-12-04", "2009-12-11", "2009-12-18", "2009-12-25", "2010-01-01", "2010-01-08", "2010-01-15", "2010-01-22", "2010-01-29", "2010-02-05", "2010-02-12", "2010-02-19", "2010-02-26", "2010-03-05", "2010-03-12", "2010-03-19", "2010-03-26", "2010-04-02", "2010-04-09", "2010-04-16", "2010-04-23", "2010-04-30", "2010-05-07", "2010-05-14", "2010-05-21", "2010-05-28", "2010-06-04", "2010-06-11", "2010-06-18", "2010-06-25", "2010-07-02", "2010-07-09", "2010-07-16", "2010-07-23", "2010-07-30", "2010-08-06", "2010-08-13", "2010-08-20", "2010-08-27", "2010-09-03", "2010-09-10", "2010-09-17", "2010-09-24", "2010-10-01", "2010-10-08", "2010-10-15", "2010-10-22", "2010-10-29", "2010-11-05", "2010-11-12", "2010-11-19", "2010-11-26", "2010-12-03", "2010-12-10", "2010-12-17", "2010-12-24", "2010-12-31", "2011-01-07", "2011-01-14", "2011-01-21", "2011-01-28", "2011-02-04", "2011-02-11", "2011-02-18", "2011-02-25", "2011-03-04", "2011-03-11", "2011-03-18", "2011-03-25", "2011-04-01", "2011-04-08", "2011-04-15", "2011-04-22", "2011-04-29", "2011-05-06", "2011-05-13", "2011-05-20", "2011-05-27", "2011-06-03", "2011-06-10", "2011-06-17", "2011-06-24", "2011-07-01", "2011-07-08", "2011-07-15", "2011-07-22", "2011-07-29", "2011-08-05", "2011-08-12", "2011-08-19", "2011-08-26", "2011-09-02", "2011-09-09", "2011-09-16", "2011-09-23", "2011-09-30", "2011-10-07", "2011-10-14", "2011-10-21", "2011-10-28", "2011-11-04", "2011-11-11", "2011-11-18", "2011-11-25", "2011-12-02", "2011-12-09", "2011-12-16", "2011-12-23", "2011-12-30", "2012-01-06", "2012-01-13", "2012-01-20", "2012-01-27", "2012-02-03", "2012-02-10", "2012-02-17", "2012-02-24", "2012-03-02", "2012-03-09", "2012-03-16", "2012-03-23", "2012-03-30", "2012-04-06", "2012-04-13", "2012-04-20", "2012-04-27", "2012-05-04", "2012-05-11", "2012-05-18", "2012-05-25", "2012-06-01", "2012-06-08", "2012-06-15", "2012-06-22", "2012-06-29", "2012-07-06", "2012-07-13", "2012-07-20", "2012-07-27", "2012-08-03", "2012-08-10", "2012-08-17", "2012-08-24", "2012-08-31", "2012-09-07", "2012-09-14", "2012-09-21", "2012-09-28", "2012-10-05", "2012-10-12", "2012-10-19", "2012-10-26", "2012-11-02", "2012-11-09", "2012-11-16", "2012-11-23", "2012-11-30", "2012-12-07", "2012-12-14", "2012-12-21", "2012-12-28", "2013-01-04", "2013-01-11", "2013-01-18", "2013-01-25", "2013-02-01", "2013-02-08", "2013-02-15", "2013-02-22", "2013-03-01", "2013-03-08", "2013-03-15", "2013-03-22", "2013-03-29", "2013-04-05", "2013-04-12", "2013-04-19", "2013-04-26", "2013-05-03", "2013-05-10", "2013-05-17", "2013-05-24", "2013-05-31", "2013-06-07", "2013-06-14", "2013-06-21", "2013-06-28", "2013-07- ...
# 'file:///Users/marenwen/env/practice_hands_on_ml/RNN/temp-plot.html'

# %%
# 好了，现在再用我们训练好的参数对未来的一周作一个小预测；然后也是把归一化的数据convert回原始数据，得到结果～65.
# Grab last week of  normalized data and reshape into shape expected by model 
scaled_last_prices = scaled[len(scaled) - prev_periods:len(scaled),:]
scaled_last_prices = np.reshape(scaled_last_prices, (1, 1, prev_periods))

print(scaled_last_prices)
# Out:
# [[[0.4103558]]]

# %%
# Predict the price for the week of 4/6/2018 using the model
# Note this will be on a scale of (0,1)
#print(new_scaled_last_prices.shape)
next_price_prediction = model.predict(scaled_last_prices)

# %%
# Transform scaled predicion back to a USD price
next_price_inverse = scaler.inverse_transform(next_price_prediction.reshape(-1, 1))
print(next_price_inverse)
# Out:
# [[65.448105]]

# %%
# Successfully complete prediction

# %% [markdown]
# # 问题

# %%
# 1. 如何用keras保存训练好的参数。
# 2. to be ocntinued...
